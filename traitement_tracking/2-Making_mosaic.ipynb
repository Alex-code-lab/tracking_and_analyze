# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon May 15 11:59:50 2023

@author: souchaud

Ce code permet d'aller créer les mosaics d'images des expériences. Le schéma des dossiers est 
défini pour un seul exemple de dossier. Cela doit être revu au cas par cas. 
"""

import os
import numpy as np
from PIL import Image
import shutil

# %%
def create_mosaic_images(positions_dir, output_dir):
    """
    Make mosaics for an experiment.

    Parameters
    ----------
    positions_dir : TYPE
        DESCRIPTION.
    output_dir : TYPE
        DESCRIPTION.

    Returns
    -------
    None.

    """
    # Récupérer la liste des dossiers de positions triés
    position_folders = sorted([f for f in os.listdir(positions_dir)
                               if os.path.isdir(os.path.join(positions_dir, f))])

    # Initialiser des listes pour stocker les informations des lignes et des colonnes
    rows = []
    # lines = []
    mosaic_line_all = []

    # Parcourir les dossiers de positions et extraire les informations des lignes et des colonnes
    for position_folder in position_folders:
        position = position_folder.split("_")
        rows.append(int(position[2]))
        # lines.append(int(position[1]))

    time = len(os.listdir(positions_dir + position_folders[0]))
    # Grouper les positions par code de temps (time code)
    for time_code in range(0, time):
        images = []

        # Parcourir les dossiers de positions
        for position_folder in position_folders:
            position = position_folder.split("_")
            current_row = int(position[2])

            # Obtenir le chemin du dossier de position et le chemin de l'image
            # corr espondante pour le code de temps actuel
            position_path = os.path.join(positions_dir, position_folder)
            image_file = sorted([f for f in os.listdir(position_path)
                                 if f.endswith(".tif")])[time_code]
            image_path = os.path.join(position_path, image_file)

            # Ouvrir l'image à l'aide de PIL (Pillow) et l'ajouter à la liste des images
            image = Image.open(image_path)
            images.append(image)

            # Si la ligne actuelle est la plus grande parmi toutes les lignes,
            # cela signifie qu'il est temps de créer une mosaïque de la ligne
            if int(current_row) == max(rows):
                # Concaténer les images de la ligne horizontalement
                mosaic_line = np.concatenate(images, axis=1)
                # Ajouter la mosaïque de ligne à la liste de toutes les mosaïques de lignes
                mosaic_line_all.append(mosaic_line)

                # Réinitialiser la liste des images pour la prochaine ligne
                images = []

        # Concaténer toutes les mosaïques de lignes horizontalement pour créer une mosaïque totale
        # mosaic_total = np.concatenate(mosaic_row_all, axis=0)
        mosaic_total = np.concatenate(mosaic_line_all[::-1], axis=0)

        # Convertir la mosaïque totale en une image PIL (Pillow)
        mosaic_image_tot_pil = Image.fromarray(mosaic_total)

        # Définir le chemin de sortie de l'image de mosaïque totale
        output_path = os.path.join(output_dir, f"mosaic_total_{time_code}.tif")

        # Enregistrer l'image de mosaïque totale sur le disque
        mosaic_image_tot_pil.save(output_path)

        # Réinitialiser les listes et les variables pour le prochain code de temps
        images = []
        mosaic_line_all = []
        mosaic_total = []

        # Afficher un message pour indiquer que l'image de mosaïque
        # totale a été enregistrée avec succès
        print(f"Mosaic total image for time code {time_code} saved at {output_path}")


def create_mosaic_images_too_heavy(positions_dir, output_dir):
    """
    Make mosaics for an experiment.

    Parameters
    ----------
    positions_dir : TYPE
        DESCRIPTION.
    output_dir : TYPE
        DESCRIPTION.

    Returns
    -------
    None.

    """
    # Récupérer la liste des dossiers de positions triés
    position_folders = sorted([f for f in os.listdir(positions_dir)
                               if os.path.isdir(os.path.join(positions_dir, f))])

    # Initialiser des listes pour stocker les informations des lignes et des colonnes
    rows = []
    lines = []

    # Parcourir les dossiers de positions et extraire les informations des lignes et des colonnes
    for position_folder in position_folders:
        position = position_folder.split("_")
        rows.append(int(position[2]))
        lines.append(int(position[1]))

    time = len(os.listdir(os.path.join(positions_dir, position_folders[0])))
    # Grouper les positions par code de temps (time code)
    for time_code in range(0, time):
        images = []
        row_num = 0
        # Parcourir les dossiers de positions
        for position_folder in position_folders:
            position = position_folder.split("_")
            current_row = int(position[2])
            current_line = int(position[1])

            # Obtenir le chemin du dossier de position et le chemin de l'image
            # correspondante pour le code de temps actuel
            position_path = os.path.join(positions_dir, position_folder)
            image_file = sorted([f for f in os.listdir(position_path)
                                 if f.endswith(".tif")])[time_code]
            image_path = os.path.join(position_path, image_file)

            # Ouvrir l'image à l'aide de PIL (Pillow) et l'ajouter à la liste des images
            image = Image.open(image_path)
            print(image_path)
            image = np.array(image)
            images.append(np.array(image))

            # Si la ligne actuelle est la plus grande parmi toutes les lignes,
            # cela signifie qu'il est temps de créer une mosaïque de la ligne
            if int(current_row) == max(rows):
                row_num += 1
                # Concaténer les images de la ligne horizontalement
                mosaic_line = np.concatenate(images, axis=1)

                # Enregistrer la mosaïque de ligne dans un dossier temporaire
                temp_output_dir = os.path.join(output_dir, "temp_mosaic_line")
                os.makedirs(temp_output_dir, exist_ok=True)
                mosaic_line_path = os.path.join(temp_output_dir,
                                                f"mosaic_line_{time_code}_{row_num}.tif")
                mosaic_line_pil = Image.fromarray(mosaic_line)
                mosaic_line_pil.save(mosaic_line_path)

                # Afficher le chemin de la mosaïque de ligne enregistrée
                print(f"Mosaic line {current_line} image for\
                      time code {time_code} saved at {mosaic_line_path}")
                # Réinitialiser la liste des images pour la prochaine ligne
                images = []

                if int(current_line) == max(lines):

                    # Ajouter le chemin de la mosaïque de ligne à la
                    # liste de toutes les mosaïques de lignes

                    fichiers = os.listdir(temp_output_dir)
                    mosaic_line_all = []  # Liste pour stocker les chemins des mosaïques de ligne

                    # Parcourez les fichiers et supprimez-les un par un
                    for fichier in fichiers:
                        mosaic_line = Image.open(mosaic_line_path)
                        mosaic_line_all.append(np.array(mosaic_line))
                        chemin_fichier = os.path.join(temp_output_dir, fichier)
                        if os.path.isfile(chemin_fichier):
                            os.remove(chemin_fichier)

                    mosaic_total = np.concatenate(mosaic_line_all, axis=0)

                    # Convertir la mosaïque totale en une image PIL (Pillow)
                    mosaic_image_tot_pil = Image.fromarray(mosaic_total)

                    # Définir le chemin de sortie de l'image de mosaïque totale
                    output_path = os.path.join(output_dir, f"mosaic_total_{time_code}.tif")

                    # Enregistrer l'image de mosaïque totale sur le disque
                    mosaic_image_tot_pil.save(output_path)

                    # Supprimer le dossier temporaire et ses fichiers intermédiaires
                    shutil.rmtree(temp_output_dir)
                    # Réinitialiser les listes et les variables pour le prochain code de temps
                    del mosaic_total, mosaic_line, mosaic_line_all, mosaic_image_tot_pil,
                    del mosaic_line_pil, images, image

            # # Concaténer toutes les mosaïques de lignes horizontalement pour créer une mosaïque totale
            # for mosaic_line_path in mosaic_line_all[::-1]:
            #     mosaic_line = Image.open(mosaic_line_path)
            #     mosaic_total.append(np.array(mosaic_line))

            # mosaic_total = np.concatenate(mosaic_total, axis=0)

            # # Convertir la mosaïque totale en une image PIL (Pillow)
            # mosaic_image_tot_pil = Image.fromarray(mosaic_total)

            # # Définir le chemin de sortie de l'image de mosaïque totale
            # output_path = os.path.join(output_dir, f"mosaic_total_{time_code}.tif")

            # # Enregistrer l'image de mosaïque totale sur le disque
            # mosaic_image_tot_pil.save(output_path)

            # # Supprimer le dossier temporaire et ses fichiers intermédiaires
            # shutil.rmtree(temp_output_dir)

            # # Afficher un message pour indiquer que l'image de mosaïque
            # # totale a été enregistrée avec succès
            # print(f"Mosaic total image for time code {time_code} saved at {output_path}")


def create_mosaic_images_agregat(positions_dir, output_dir):
    """
    Make mosaics for an experiment.

    Parameters
    ----------
    positions_dir : TYPE
        DESCRIPTION.
    output_dir : TYPE
        DESCRIPTION.

    Returns
    -------
    None.

    """
    # Récupérer la liste des dossiers de positions triés
    position_folders = sorted([f for f in os.listdir(positions_dir)
                               if os.path.isdir(os.path.join(positions_dir, f))])

    # Initialiser des listes pour stocker les informations des lignes et des colonnes
    rows = []
    lines = []
    mosaic_line_all = []

    # Parcourir les dossiers de positions et extraire les informations des lignes et des colonnes
    for position_folder in position_folders:
        position = position_folder.split("_")
        rows.append(int(position[2]))
        lines.append(int(position[1]))

    # Grouper les positions par code de temps (time code)
    for time_code in range(0, 240):
        images = []

        # Parcourir les dossiers de positions
        for position_folder in position_folders:
            position = position_folder.split("_")
            current_row = int(position[2])
            print(current_row)

            # Obtenir le chemin du dossier de position et le chemin de l'image
            # correspondante pour le code de temps actuel
            position_path = os.path.join(positions_dir, position_folder)
            image_file = sorted([f for f in os.listdir(position_path)
                                 if f.endswith(".tif")])[time_code]
            image_path = os.path.join(position_path, image_file)

            # Ouvrir l'image à l'aide de PIL (Pillow) et l'ajouter à la liste des images
            image = Image.open(image_path)
            images.append(image)

            # Si la ligne actuelle est la plus grande parmi toutes les lignes,
            # cela signifie qu'il est temps de créer une mosaïque de la ligne
            if int(current_row) == max(rows):
                # Concaténer les images de la ligne horizontalement
                mosaic_line = np.concatenate(images, axis=1)
                # Ajouter la mosaïque de ligne à la liste de toutes les mosaïques de lignes
                mosaic_line_all.append(mosaic_line)

                # Réinitialiser la liste des images pour la prochaine ligne
                images = []

        # Concaténer toutes les mosaïques de lignes horizontalement pour créer une mosaïque totale
        # mosaic_total = np.concatenate(mosaic_row_all, axis=0)
        mosaic_total = np.concatenate(mosaic_line_all[::-1], axis=0)

        # Convertir la mosaïque totale en une image PIL (Pillow)
        mosaic_image_tot_pil = Image.fromarray(mosaic_total)

        # Définir le chemin de sortie de l'image de mosaïque totale
        output_path = os.path.join(output_dir, f"mosaic_total_{time_code}.tif")

        # Enregistrer l'image de mosaïque totale sur le disque
        mosaic_image_tot_pil.save(output_path)

        # Réinitialiser les listes et les variables pour le prochain code de temps
        images = []
        mosaic_line_all = []
        mosaic_total = []

        # Afficher un message pour indiquer que l'image de mosaïque
        # totale a été enregistrée avec succès
        print(f"Mosaic total image for time code {time_code} saved at {output_path}")


# # Specify the directories for specific names
# # positions_dir =
# '/Users/souchaud/Desktop/2022_12_09_ASMOT035_BoiteNonT_SorC_15s_5x_P6_AX3Chi2_t90/'
# # output_dir = '/Users/souchaud/Desktop/coucou/'

# # Specify the directories
# positions_dir = '/Users/souchaud/Desktop/2023_02_06_EmAg001_4.3-10-6-AX3_Chi1-p1/'
# name = re.search('Ag[0-9]{3}', positions_dir).group() + "_MOSAIC"
# output_dir = f'/Users/souchaud/Desktop/{name}/'
# if os.path.exists(output_dir):
#     shutil.rmtree(output_dir)
# if not os.path.exists(output_dir):
#     os.mkdir(output_dir)


# # Create mosaic images for each time code
# create_mosaic_images_agregat(positions_dir, output_dir)


# Specify the directories

# %%
manip_names = []
# position_folders = '/Volumes/Labo_Alex_Mac/A_analyser/CytoOne_HL5/to_convert/'
condition = 'CytoOne_HL5_AMPC_10x'
position_folders = f'/Users/souchaud/Desktop/A_analyser/{condition}/'

# %%
manip_names = [f for f in os.listdir(position_folders) if
               os.path.isdir(os.path.join(position_folders, f))]


# '/Volumes/Labo-Dicty/Alex/A_analyser/CytoOne_SorC/'
for manip_name in manip_names:
    positions_dir = position_folders + manip_name + '/8bits/'
    output_dir = position_folders + manip_name + '/mosaic/'
    if not os.path.exists(positions_dir):
        print(positions_dir)
        continue
    if os.path.exists(output_dir):
        continue
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # Create mosaic images for each time code
    create_mosaic_images(positions_dir, output_dir)
    # create_mosaic_images_too_heavy(positions_dir, output_dir)
# Out:
# Mosaic total image for time code 0 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_0.tif
# Mosaic total image for time code 1 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_1.tif
# Mosaic total image for time code 2 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_2.tif
# Mosaic total image for time code 3 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_3.tif
# Mosaic total image for time code 4 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_4.tif
# Mosaic total image for time code 5 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_5.tif
# Mosaic total image for time code 6 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_6.tif
# Mosaic total image for time code 7 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_7.tif
# Mosaic total image for time code 8 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_8.tif
# Mosaic total image for time code 9 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_9.tif
# Mosaic total image for time code 10 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_10.tif
# Mosaic total image for time code 11 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_11.tif
# Mosaic total image for time code 12 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_12.tif
# Mosaic total image for time code 13 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_13.tif
# Mosaic total image for time code 14 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_14.tif
# Mosaic total image for time code 15 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_15.tif
# Mosaic total image for time code 16 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_16.tif
# Mosaic total image for time code 17 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_17.tif
# Mosaic total image for time code 18 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_18.tif
# Mosaic total image for time code 19 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_19.tif
# Mosaic total image for time code 20 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_20.tif
# Mosaic total image for time code 21 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_21.tif
# Mosaic total image for time code 22 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_22.tif
# Mosaic total image for time code 23 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_23.tif
# Mosaic total image for time code 24 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_24.tif
# Mosaic total image for time code 25 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_25.tif
# Mosaic total image for time code 26 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_26.tif
# Mosaic total image for time code 27 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_27.tif
# Mosaic total image for time code 28 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_28.tif
# Mosaic total image for time code 29 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_29.tif
# Mosaic total image for time code 30 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_30.tif
# Mosaic total image for time code 31 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_31.tif
# Mosaic total image for time code 32 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_32.tif
# Mosaic total image for time code 33 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_33.tif
# Mosaic total image for time code 34 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_34.tif
# Mosaic total image for time code 35 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_35.tif
# Mosaic total image for time code 36 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_36.tif
# Mosaic total image for time code 37 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_37.tif
# Mosaic total image for time code 38 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_38.tif
# Mosaic total image for time code 39 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_39.tif
# Mosaic total image for time code 40 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_40.tif
# Mosaic total image for time code 41 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_41.tif
# Mosaic total image for time code 42 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_42.tif
# Mosaic total image for time code 43 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_43.tif
# Mosaic total image for time code 44 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_44.tif
# Mosaic total image for time code 45 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_45.tif
# Mosaic total image for time code 46 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_46.tif
# Mosaic total image for time code 47 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_47.tif
# Mosaic total image for time code 48 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_48.tif
# Mosaic total image for time code 49 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_49.tif
# Mosaic total image for time code 50 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_50.tif
# Mosaic total image for time code 51 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_51.tif
# Mosaic total image for time code 52 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_52.tif
# Mosaic total image for time code 53 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_53.tif
# Mosaic total image for time code 54 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_54.tif
# Mosaic total image for time code 55 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_55.tif
# Mosaic total image for time code 56 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_56.tif
# Mosaic total image for time code 57 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_57.tif
# Mosaic total image for time code 58 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_58.tif
# Mosaic total image for time code 59 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_59.tif
# Mosaic total image for time code 60 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_60.tif
# Mosaic total image for time code 61 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_61.tif
# Mosaic total image for time code 62 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_62.tif
# Mosaic total image for time code 63 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_63.tif
# Mosaic total image for time code 64 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_64.tif
# Mosaic total image for time code 65 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_65.tif
# Mosaic total image for time code 66 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_66.tif
# Mosaic total image for time code 67 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_67.tif
# Mosaic total image for time code 68 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_68.tif
# Mosaic total image for time code 69 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_69.tif
# Mosaic total image for time code 70 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_70.tif
# Mosaic total image for time code 71 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_71.tif
# Mosaic total image for time code 72 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_72.tif
# Mosaic total image for time code 73 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_73.tif
# Mosaic total image for time code 74 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_74.tif
# Mosaic total image for time code 75 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_75.tif
# Mosaic total image for time code 76 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_76.tif
# Mosaic total image for time code 77 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_77.tif
# Mosaic total image for time code 78 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_78.tif
# Mosaic total image for time code 79 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_79.tif
# Mosaic total image for time code 80 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_80.tif
# Mosaic total image for time code 81 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_81.tif
# Mosaic total image for time code 82 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_82.tif
# Mosaic total image for time code 83 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_83.tif
# Mosaic total image for time code 84 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_84.tif
# Mosaic total image for time code 85 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_85.tif
# Mosaic total image for time code 86 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_86.tif
# Mosaic total image for time code 87 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_87.tif
# Mosaic total image for time code 88 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_88.tif
# Mosaic total image for time code 89 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_89.tif
# Mosaic total image for time code 90 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_90.tif
# Mosaic total image for time code 91 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_91.tif
# Mosaic total image for time code 92 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_92.tif
# Mosaic total image for time code 93 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_93.tif
# Mosaic total image for time code 94 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_94.tif
# Mosaic total image for time code 95 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_95.tif
# Mosaic total image for time code 96 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_96.tif
# Mosaic total image for time code 97 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_97.tif
# Mosaic total image for time code 98 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_98.tif
# Mosaic total image for time code 99 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_99.tif
# Mosaic total image for time code 100 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_100.tif
# Mosaic total image for time code 101 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_101.tif
# Mosaic total image for time code 102 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_102.tif
# Mosaic total image for time code 103 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_103.tif
# Mosaic total image for time code 104 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_104.tif
# Mosaic total image for time code 105 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_105.tif
# Mosaic total image for time code 106 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_106.tif
# Mosaic total image for time code 107 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_107.tif
# Mosaic total image for time code 108 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_108.tif
# Mosaic total image for time code 109 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_109.tif
# Mosaic total image for time code 110 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_110.tif
# Mosaic total image for time code 111 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_111.tif
# Mosaic total image for time code 112 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_112.tif
# Mosaic total image for time code 113 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_113.tif
# Mosaic total image for time code 114 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_114.tif
# Mosaic total image for time code 115 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_115.tif
# Mosaic total image for time code 116 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_116.tif
# Mosaic total image for time code 117 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_117.tif
# Mosaic total image for time code 118 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_118.tif
# Mosaic total image for time code 119 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_119.tif
# Mosaic total image for time code 120 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_120.tif
# Mosaic total image for time code 121 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_121.tif
# Mosaic total image for time code 122 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_122.tif
# Mosaic total image for time code 123 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_123.tif
# Mosaic total image for time code 124 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_124.tif
# Mosaic total image for time code 125 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_125.tif
# Mosaic total image for time code 126 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_126.tif
# Mosaic total image for time code 127 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_127.tif
# Mosaic total image for time code 128 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_128.tif
# Mosaic total image for time code 129 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_129.tif
# Mosaic total image for time code 130 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_130.tif
# Mosaic total image for time code 131 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_131.tif
# Mosaic total image for time code 132 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_132.tif
# Mosaic total image for time code 133 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_133.tif
# Mosaic total image for time code 134 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_134.tif
# Mosaic total image for time code 135 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_135.tif
# Mosaic total image for time code 136 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_136.tif
# Mosaic total image for time code 137 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_137.tif
# Mosaic total image for time code 138 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_138.tif
# Mosaic total image for time code 139 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_139.tif
# Mosaic total image for time code 140 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_140.tif
# Mosaic total image for time code 141 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_141.tif
# Mosaic total image for time code 142 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_142.tif
# Mosaic total image for time code 143 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_143.tif
# Mosaic total image for time code 144 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_144.tif
# Mosaic total image for time code 145 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_145.tif
# Mosaic total image for time code 146 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_146.tif
# Mosaic total image for time code 147 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_147.tif
# Mosaic total image for time code 148 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_148.tif
# Mosaic total image for time code 149 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_149.tif
# Mosaic total image for time code 150 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_150.tif
# Mosaic total image for time code 151 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_151.tif
# Mosaic total image for time code 152 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_152.tif
# Mosaic total image for time code 153 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_153.tif
# Mosaic total image for time code 154 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_154.tif
# Mosaic total image for time code 155 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_155.tif
# Mosaic total image for time code 156 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_156.tif
# Mosaic total image for time code 157 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_157.tif
# Mosaic total image for time code 158 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_158.tif
# Mosaic total image for time code 159 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_159.tif
# Mosaic total image for time code 160 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_160.tif
# Mosaic total image for time code 161 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_161.tif
# Mosaic total image for time code 162 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_162.tif
# Mosaic total image for time code 163 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_163.tif
# Mosaic total image for time code 164 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_164.tif
# Mosaic total image for time code 165 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_165.tif
# Mosaic total image for time code 166 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_166.tif
# Mosaic total image for time code 167 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_167.tif
# Mosaic total image for time code 168 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_168.tif
# Mosaic total image for time code 169 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_169.tif
# Mosaic total image for time code 170 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_170.tif
# Mosaic total image for time code 171 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_171.tif
# Mosaic total image for time code 172 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_172.tif
# Mosaic total image for time code 173 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_173.tif
# Mosaic total image for time code 174 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_174.tif
# Mosaic total image for time code 175 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_175.tif
# Mosaic total image for time code 176 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_176.tif
# Mosaic total image for time code 177 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_177.tif
# Mosaic total image for time code 178 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_178.tif
# Mosaic total image for time code 179 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_179.tif
# Mosaic total image for time code 180 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_180.tif
# Mosaic total image for time code 181 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_181.tif
# Mosaic total image for time code 182 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_182.tif
# Mosaic total image for time code 183 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_183.tif
# Mosaic total image for time code 184 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_184.tif
# Mosaic total image for time code 185 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_185.tif
# Mosaic total image for time code 186 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_186.tif
# Mosaic total image for time code 187 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_187.tif
# Mosaic total image for time code 188 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_188.tif
# Mosaic total image for time code 189 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_189.tif
# Mosaic total image for time code 190 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_190.tif
# Mosaic total image for time code 191 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_191.tif
# Mosaic total image for time code 192 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_192.tif
# Mosaic total image for time code 193 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_193.tif
# Mosaic total image for time code 194 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_194.tif
# Mosaic total image for time code 195 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_195.tif
# Mosaic total image for time code 196 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_196.tif
# Mosaic total image for time code 197 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_197.tif
# Mosaic total image for time code 198 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_198.tif
# Mosaic total image for time code 199 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_199.tif
# Mosaic total image for time code 200 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_200.tif
# Mosaic total image for time code 201 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_201.tif
# Mosaic total image for time code 202 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_202.tif
# Mosaic total image for time code 203 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_203.tif
# Mosaic total image for time code 204 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_204.tif
# Mosaic total image for time code 205 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_205.tif
# Mosaic total image for time code 206 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_206.tif
# Mosaic total image for time code 207 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_207.tif
# Mosaic total image for time code 208 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_208.tif
# Mosaic total image for time code 209 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_209.tif
# Mosaic total image for time code 210 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_210.tif
# Mosaic total image for time code 211 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_211.tif
# Mosaic total image for time code 212 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_212.tif
# Mosaic total image for time code 213 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_213.tif
# Mosaic total image for time code 214 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_214.tif
# Mosaic total image for time code 215 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_215.tif
# Mosaic total image for time code 216 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_216.tif
# Mosaic total image for time code 217 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_217.tif
# Mosaic total image for time code 218 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_218.tif
# Mosaic total image for time code 219 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_219.tif
# Mosaic total image for time code 220 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_220.tif
# Mosaic total image for time code 221 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_221.tif
# Mosaic total image for time code 222 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_222.tif
# Mosaic total image for time code 223 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_223.tif
# Mosaic total image for time code 224 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_224.tif
# Mosaic total image for time code 225 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_225.tif
# Mosaic total image for time code 226 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_226.tif
# Mosaic total image for time code 227 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_227.tif
# Mosaic total image for time code 228 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_228.tif
# Mosaic total image for time code 229 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT275_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0225-14h30_SorC1000/mosaic/mosaic_total_229.tif
# ...
# Mosaic total image for time code 284 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_284.tif
# Mosaic total image for time code 285 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_285.tif
# Mosaic total image for time code 286 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_286.tif
# Mosaic total image for time code 287 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_287.tif
# Mosaic total image for time code 288 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_288.tif
# Mosaic total image for time code 289 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_289.tif
# Mosaic total image for time code 290 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_290.tif
# Mosaic total image for time code 291 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_291.tif
# Mosaic total image for time code 292 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_292.tif
# Mosaic total image for time code 293 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_293.tif
# Mosaic total image for time code 294 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_294.tif
# Mosaic total image for time code 295 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_295.tif
# Mosaic total image for time code 296 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_296.tif
# Mosaic total image for time code 297 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_297.tif
# Mosaic total image for time code 298 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_298.tif
# Mosaic total image for time code 299 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_299.tif
# Mosaic total image for time code 300 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_300.tif
# Mosaic total image for time code 301 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_301.tif
# Mosaic total image for time code 302 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_302.tif
# Mosaic total image for time code 303 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_303.tif
# Mosaic total image for time code 304 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_304.tif
# Mosaic total image for time code 305 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_305.tif
# Mosaic total image for time code 306 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_306.tif
# Mosaic total image for time code 307 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_307.tif
# Mosaic total image for time code 308 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_308.tif
# Mosaic total image for time code 309 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_309.tif
# Mosaic total image for time code 310 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_310.tif
# Mosaic total image for time code 311 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_311.tif
# Mosaic total image for time code 312 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_312.tif
# Mosaic total image for time code 313 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_313.tif
# Mosaic total image for time code 314 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_314.tif
# Mosaic total image for time code 315 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_315.tif
# Mosaic total image for time code 316 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_316.tif
# Mosaic total image for time code 317 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_317.tif
# Mosaic total image for time code 318 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_318.tif
# Mosaic total image for time code 319 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_319.tif
# Mosaic total image for time code 320 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_320.tif
# Mosaic total image for time code 321 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_321.tif
# Mosaic total image for time code 322 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_322.tif
# Mosaic total image for time code 323 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_323.tif
# Mosaic total image for time code 324 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_324.tif
# Mosaic total image for time code 325 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_325.tif
# Mosaic total image for time code 326 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_326.tif
# Mosaic total image for time code 327 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_327.tif
# Mosaic total image for time code 328 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_328.tif
# Mosaic total image for time code 329 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_329.tif
# Mosaic total image for time code 330 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_330.tif
# Mosaic total image for time code 331 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_331.tif
# Mosaic total image for time code 332 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_332.tif
# Mosaic total image for time code 333 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_333.tif
# Mosaic total image for time code 334 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_334.tif
# Mosaic total image for time code 335 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_335.tif
# Mosaic total image for time code 336 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_336.tif
# Mosaic total image for time code 337 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_337.tif
# Mosaic total image for time code 338 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_338.tif
# Mosaic total image for time code 339 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_339.tif
# Mosaic total image for time code 340 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_340.tif
# Mosaic total image for time code 341 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_341.tif
# Mosaic total image for time code 342 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_342.tif
# Mosaic total image for time code 343 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_343.tif
# Mosaic total image for time code 344 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_344.tif
# Mosaic total image for time code 345 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_345.tif
# Mosaic total image for time code 346 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_346.tif
# Mosaic total image for time code 347 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_347.tif
# Mosaic total image for time code 348 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_348.tif
# Mosaic total image for time code 349 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_349.tif
# Mosaic total image for time code 350 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_350.tif
# Mosaic total image for time code 351 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_351.tif
# Mosaic total image for time code 352 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_352.tif
# Mosaic total image for time code 353 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_353.tif
# Mosaic total image for time code 354 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_354.tif
# Mosaic total image for time code 355 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_355.tif
# Mosaic total image for time code 356 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_356.tif
# Mosaic total image for time code 357 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_357.tif
# Mosaic total image for time code 358 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_358.tif
# Mosaic total image for time code 359 saved at /Users/souchaud/Desktop/A_analyser/CytoOne_HL5_AMPC_10x/2025_02_25_ASMOT278_AX3_MAT_P3_10x_CytoOnne_HL5_0225-10h30-0226-15h20_SorC1000/mosaic/mosaic_total_359.tif
